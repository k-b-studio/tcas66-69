# %% [markdown]
# # TCAS stats clean

# %% [markdown]
# ## Config

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df66 = pd.read_excel("/Users/kbstudio/Library/CloudStorage/OneDrive-Personal/Project/tcas/data/TCAS66_maxmin.xlsx")
df67 = pd.read_excel("/Users/kbstudio/Library/CloudStorage/OneDrive-Personal/Project/tcas/data/TCAS67_maxmin.xlsx")
df68 = pd.read_excel("/Users/kbstudio/Library/CloudStorage/OneDrive-Personal/Project/tcas/data/TCAS68_maxmin.xlsx")
df69 = pd.read_excel("/Users/kbstudio/Library/CloudStorage/OneDrive-Personal/Project/tcas/data/TCAS69_maxmin.xlsx")

# %%
df68.head()
# Out:
#                   สถาบัน      วิทยาเขต     รหัสหลักสูตร                คณะ  \
# 0  จุฬาลงกรณ์มหาวิทยาลัย  วิทยาเขตหลัก  10010121300001A  คณะวิศวกรรมศาสตร์
# 1  จุฬาลงกรณ์มหาวิทยาลัย  วิทยาเขตหลัก  10010121300501A  คณะวิศวกรรมศาสตร์
# 2  จุฬาลงกรณ์มหาวิทยาลัย  วิทยาเขตหลัก  10010121300599A  คณะวิศวกรรมศาสตร์
# 3  จุฬาลงกรณ์มหาวิทยาลัย  วิทยาเขตหลัก  10010121301101A  คณะวิศวกรรมศาสตร์
# 4  จุฬาลงกรณ์มหาวิทยาลัย  วิทยาเขตหลัก  10010121302101A  คณะวิศวกรรมศาสตร์
#
#                                             หลักสูตร รายละเอียด สาขา/วิชาเอก  \
# 0  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมศา...        NaN            0
# 1  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...        NaN            0
# 2  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมคอ...        NaN            0
# 3  หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมนิ...        NaN            0
# 4   หลักสูตรวิศวกรรมศาสตรบัณฑิต สาขาวิชาวิศวกรรมโยธา        NaN            0
#
# ...

# %%
print(f"66: {len(df66)} rows,\n67: {len(df67)} rows,\n68: {len(df68)} rows,\n69: {len(df69)} rows")
print()
print("== Faculty counts ==")
print(f"66: {len(df66['คณะ/สำนักวิชา'].unique())}")
print()
# Out:
# 66: 4670 rows,
# 67: 4718 rows,
# 68: 4945 rows,
# 69: 5104 rows
#
# == Faculty counts ==
# 66: 436

# %%
print()
